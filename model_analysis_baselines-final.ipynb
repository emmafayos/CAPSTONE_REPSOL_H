# %%
import pandas as pd
import seaborn as sns
import datetime as dt
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score, mean_absolute_error


# Libraries for Forecasting
import pandas as pd
import numpy as np
import warnings
import itertools
import matplotlib
import matplotlib.pyplot as plt
import datetime
from pylab import rcParams
import statsmodels.api as sm
from statsmodels.tsa.api import ExponentialSmoothing, SimpleExpSmoothing, Holt
from statsmodels.tsa.stattools import adfuller
from sklearn import preprocessing
from pycaret.regression import *

# Ignore the warning, can comment this 
warnings.filterwarnings("ignore")

# %% [markdown]
# # Different Baselines

# %% [markdown]
# #### Numero para hacer mas rápido el notebook. (la version final debe llevar número = 100, pero se va a tardar el notebook en correr)

# %%
numero = 100

# %%
df_repsol = pd.read_csv('df_repsol_wo_FE.csv', index_col=1).drop(columns = ["Unnamed: 0"])
df_repsol["station"] = df_repsol["station"].str[2:]
df_repsol["station"] = df_repsol["station"].astype(int)

# %%
le = preprocessing.LabelEncoder()
df_repsol['municipality'] = le.fit_transform(df_repsol["municipality"].values)

# %%
df_repsol['producto'] = 0
df_repsol.loc[df_repsol['product'] == '95', 'producto'] = 1

# %%
columns_strings = df_repsol.dtypes[df_repsol.dtypes == "object"].index
columns_strings
# Out:
# Index(['product', 'horaracha', 'horatmax', 'horatmin', 'coordinates',
#        'provinces'],
#       dtype='object')

# %%
def r2_rmse(data):
    r2 = r2_score(data['sales_norm'], data['Label'] )
    mae =  mean_absolute_error(data['sales_norm'], data['Label'])
    return pd.Series(dict(mae = mae, r2 = r2))

# %%
df_repsol_model = df_repsol.drop(columns = columns_strings)
df_repsol_model.dropna(inplace = True)

# %%
global_train = df_repsol_model.loc[(df_repsol_model.index >= '2016-01-01')
                     & (df_repsol_model.index <= '2018-12-31')]

global_test = df_repsol_model.loc[(df_repsol_model.index >= '2019-01-01')
                     & (df_repsol_model.index <= '2019-01-31')]

# %% [markdown]
# # 1. Model predictions without Feature Engineering; Global model w/o Feature Engineering using pycaret

# %% [markdown]
# We then create a Global Model by testing diferent algorithms such as Lightgbm, Xgboost and Random Forest Regressor

# %%
df_repsol_model = df_repsol.drop(columns = columns_strings)
df_repsol_model.dropna(inplace = True)

# %%
global_train = df_repsol_model.loc[(df_repsol_model.index >= '2016-01-01')
                     & (df_repsol_model.index <= '2018-12-31')]

global_test = df_repsol_model.loc[(df_repsol_model.index >= '2019-01-01')
                     & (df_repsol_model.index <= '2019-01-31')]

# %%
X_train_global = global_train.drop("sales_norm", axis=1)
Y_train_global = global_train["sales_norm"]

X_test_global = global_test.drop("sales_norm", axis=1)
Y_test_global = global_test["sales_norm"]

# %%
setup1 = setup(data = global_train,  target = "sales_norm", silent = True)
# Out:
# <style type="text/css">
# #T_93ddb_row42_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_93ddb_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_93ddb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_93ddb_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_93ddb_row0_col1" class="data row0 col1" >856</td>
#     </tr>
#     <tr>
#       <th id="T_93ddb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_93ddb_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_93ddb_row1_col1" class="data row1 col1" >sales_norm</td>
#     </tr>
#     <tr>
#       <th id="T_93ddb_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_93ddb_row2_col0" class="data row2 col0" >Original Data</td>
#       <td id="T_93ddb_row2_col1" class="data row2 col1" >(24992, 36)</td>
#     </tr>
#     <tr>
#       <th id="T_93ddb_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_93ddb_row3_col0" class="data row3 col0" >Missing Values</td>
#       <td id="T_93ddb_row3_col1" class="data row3 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_93ddb_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_93ddb_row4_col0" class="data row4 col0" >Numeric Features</td>
#       <td id="T_93ddb_row4_col1" class="data row4 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_93ddb_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_93ddb_row5_col0" class="data row5 col0" >Categorical Features</td>
#       <td id="T_93ddb_row5_col1" class="data row5 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_93ddb_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_93ddb_row6_col0" class="data row6 col0" >Ordinal Features</td>
#       <td id="T_93ddb_row6_col1" class="data row6 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_93ddb_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_93ddb_row7_col0" class="data row7 col0" >High Cardinality Features</td>
#       <td id="T_93ddb_row7_col1" class="data row7 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_93ddb_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_93ddb_row8_col0" class="data row8 col0" >High Cardinality Method</td>
#       <td id="T_93ddb_row8_col1" class="data row8 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_93ddb_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_93ddb_row9_col0" class="data row9 col0" >Transformed Train Set</td>
#       <td id="T_93ddb_row9_col1" class="data row9 col1" >(17494, 49)</td>
#     </tr>
#     <tr>
#       <th id="T_93ddb_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_93ddb_row10_col0" class="data row10 col0" >Transformed Test Set</td>
#       <td id="T_93ddb_row10_col1" class="data row10 col1" >(7498, 49)</td>
#     </tr>
#     <tr>
#       <th id="T_93ddb_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_93ddb_row11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#       <td id="T_93ddb_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_93ddb_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_93ddb_row12_col0" class="data row12 col0" >Stratify Train-Test</td>
#       <td id="T_93ddb_row12_col1" class="data row12 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_93ddb_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_93ddb_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_93ddb_row13_col1" class="data row13 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_93ddb_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_93ddb_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_93ddb_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_93ddb_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_93ddb_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_93ddb_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_93ddb_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_93ddb_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_93ddb_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_93ddb_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_93ddb_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_93ddb_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_93ddb_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_93ddb_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_93ddb_row18_col1" class="data row18 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_93ddb_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_93ddb_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_93ddb_row19_col1" class="data row19 col1" >0724</td>
#     </tr>
#     <tr>
#       <th id="T_93ddb_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_93ddb_row20_col0" class="data row20 col0" >Imputation Type</td>
#       <td id="T_93ddb_row20_col1" class="data row20 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_93ddb_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_93ddb_row21_col0" class="data row21 col0" >Iterative Imputation Iteration</td>
#       <td id="T_93ddb_row21_col1" class="data row21 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_93ddb_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_93ddb_row22_col0" class="data row22 col0" >Numeric Imputer</td>
#       <td id="T_93ddb_row22_col1" class="data row22 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_93ddb_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_93ddb_row23_col0" class="data row23 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_93ddb_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_93ddb_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_93ddb_row24_col0" class="data row24 col0" >Categorical Imputer</td>
#       <td id="T_93ddb_row24_col1" class="data row24 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_93ddb_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_93ddb_row25_col0" class="data row25 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_93ddb_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_93ddb_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_93ddb_row26_col0" class="data row26 col0" >Unknown Categoricals Handling</td>
#       <td id="T_93ddb_row26_col1" class="data row26 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_93ddb_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_93ddb_row27_col0" class="data row27 col0" >Normalize</td>
#       <td id="T_93ddb_row27_col1" class="data row27 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_93ddb_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_93ddb_row28_col0" class="data row28 col0" >Normalize Method</td>
#       <td id="T_93ddb_row28_col1" class="data row28 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_93ddb_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_93ddb_row29_col0" class="data row29 col0" >Transformation</td>
#       <td id="T_93ddb_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_93ddb_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_93ddb_row30_col0" class="data row30 col0" >Transformation Method</td>
#       <td id="T_93ddb_row30_col1" class="data row30 col1" >None</td>
#     </tr>

# %%
best_global = compare_models(sort="R2", exclude = ["lar", "huber", "par", "llar", "knn", "lasso", "en"])
# Out:
# <style type="text/css">
# #T_ac62b_ th {
#   text-align: left;
# }
# #T_ac62b_row0_col0, #T_ac62b_row0_col1, #T_ac62b_row0_col5, #T_ac62b_row0_col6, #T_ac62b_row1_col0, #T_ac62b_row1_col1, #T_ac62b_row1_col2, #T_ac62b_row1_col3, #T_ac62b_row1_col4, #T_ac62b_row1_col5, #T_ac62b_row1_col6, #T_ac62b_row2_col0, #T_ac62b_row2_col1, #T_ac62b_row2_col2, #T_ac62b_row2_col3, #T_ac62b_row2_col4, #T_ac62b_row2_col5, #T_ac62b_row2_col6, #T_ac62b_row3_col0, #T_ac62b_row3_col1, #T_ac62b_row3_col2, #T_ac62b_row3_col3, #T_ac62b_row3_col4, #T_ac62b_row3_col5, #T_ac62b_row3_col6, #T_ac62b_row4_col0, #T_ac62b_row4_col1, #T_ac62b_row4_col2, #T_ac62b_row4_col3, #T_ac62b_row4_col4, #T_ac62b_row4_col5, #T_ac62b_row4_col6, #T_ac62b_row5_col0, #T_ac62b_row5_col1, #T_ac62b_row5_col2, #T_ac62b_row5_col3, #T_ac62b_row5_col4, #T_ac62b_row5_col5, #T_ac62b_row5_col6, #T_ac62b_row6_col0, #T_ac62b_row6_col1, #T_ac62b_row6_col2, #T_ac62b_row6_col3, #T_ac62b_row6_col4, #T_ac62b_row6_col5, #T_ac62b_row6_col6, #T_ac62b_row7_col0, #T_ac62b_row7_col1, #T_ac62b_row7_col2, #T_ac62b_row7_col3, #T_ac62b_row7_col4, #T_ac62b_row7_col5, #T_ac62b_row7_col6, #T_ac62b_row8_col0, #T_ac62b_row8_col1, #T_ac62b_row8_col2, #T_ac62b_row8_col3, #T_ac62b_row8_col4, #T_ac62b_row8_col5, #T_ac62b_row8_col6, #T_ac62b_row9_col0, #T_ac62b_row9_col1, #T_ac62b_row9_col2, #T_ac62b_row9_col3, #T_ac62b_row9_col4, #T_ac62b_row9_col5, #T_ac62b_row9_col6, #T_ac62b_row10_col0, #T_ac62b_row10_col2, #T_ac62b_row10_col3, #T_ac62b_row10_col4, #T_ac62b_row11_col0, #T_ac62b_row11_col1, #T_ac62b_row11_col2, #T_ac62b_row11_col3, #T_ac62b_row11_col4, #T_ac62b_row11_col5, #T_ac62b_row11_col6 {
#   text-align: left;
# }
# #T_ac62b_row0_col2, #T_ac62b_row0_col3, #T_ac62b_row0_col4, #T_ac62b_row10_col1, #T_ac62b_row10_col5, #T_ac62b_row10_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_ac62b_row0_col7, #T_ac62b_row1_col7, #T_ac62b_row2_col7, #T_ac62b_row3_col7, #T_ac62b_row5_col7, #T_ac62b_row6_col7, #T_ac62b_row7_col7, #T_ac62b_row8_col7, #T_ac62b_row9_col7, #T_ac62b_row10_col7, #T_ac62b_row11_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_ac62b_row4_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_ac62b_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >MAE</th>
#       <th class="col_heading level0 col2" >MSE</th>
#       <th class="col_heading level0 col3" >RMSE</th>
#       <th class="col_heading level0 col4" >R2</th>
#       <th class="col_heading level0 col5" >RMSLE</th>
#       <th class="col_heading level0 col6" >MAPE</th>
#       <th class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ac62b_level0_row0" class="row_heading level0 row0" >omp</th>
#       <td id="T_ac62b_row0_col0" class="data row0 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_ac62b_row0_col1" class="data row0 col1" >0.1117</td>
#       <td id="T_ac62b_row0_col2" class="data row0 col2" >2.5802</td>
#       <td id="T_ac62b_row0_col3" class="data row0 col3" >0.6277</td>
#       <td id="T_ac62b_row0_col4" class="data row0 col4" >0.5982</td>
#       <td id="T_ac62b_row0_col5" class="data row0 col5" >0.1005</td>
#       <td id="T_ac62b_row0_col6" class="data row0 col6" >0.7899</td>
#       <td id="T_ac62b_row0_col7" class="data row0 col7" >0.0280</td>
#     </tr>
#     <tr>
#       <th id="T_ac62b_level0_row1" class="row_heading level0 row1" >ridge</th>
#       <td id="T_ac62b_row1_col0" class="data row1 col0" >Ridge Regression</td>
#       <td id="T_ac62b_row1_col1" class="data row1 col1" >0.1103</td>
#       <td id="T_ac62b_row1_col2" class="data row1 col2" >2.5808</td>
#       <td id="T_ac62b_row1_col3" class="data row1 col3" >0.6286</td>
#       <td id="T_ac62b_row1_col4" class="data row1 col4" >0.5941</td>
#       <td id="T_ac62b_row1_col5" class="data row1 col5" >0.1008</td>
#       <td id="T_ac62b_row1_col6" class="data row1 col6" >0.7696</td>
#       <td id="T_ac62b_row1_col7" class="data row1 col7" >0.0290</td>
#     </tr>
#     <tr>
#       <th id="T_ac62b_level0_row2" class="row_heading level0 row2" >lr</th>
#       <td id="T_ac62b_row2_col0" class="data row2 col0" >Linear Regression</td>
#       <td id="T_ac62b_row2_col1" class="data row2 col1" >0.1112</td>
#       <td id="T_ac62b_row2_col2" class="data row2 col2" >2.5811</td>
#       <td id="T_ac62b_row2_col3" class="data row2 col3" >0.6295</td>
#       <td id="T_ac62b_row2_col4" class="data row2 col4" >0.5891</td>
#       <td id="T_ac62b_row2_col5" class="data row2 col5" >0.1016</td>
#       <td id="T_ac62b_row2_col6" class="data row2 col6" >0.7743</td>
#       <td id="T_ac62b_row2_col7" class="data row2 col7" >0.0390</td>
#     </tr>
#     <tr>
#       <th id="T_ac62b_level0_row3" class="row_heading level0 row3" >br</th>
#       <td id="T_ac62b_row3_col0" class="data row3 col0" >Bayesian Ridge</td>
#       <td id="T_ac62b_row3_col1" class="data row3 col1" >0.1135</td>
#       <td id="T_ac62b_row3_col2" class="data row3 col2" >2.5815</td>
#       <td id="T_ac62b_row3_col3" class="data row3 col3" >0.6309</td>
#       <td id="T_ac62b_row3_col4" class="data row3 col4" >0.5815</td>
#       <td id="T_ac62b_row3_col5" class="data row3 col5" >0.1020</td>
#       <td id="T_ac62b_row3_col6" class="data row3 col6" >0.8115</td>
#       <td id="T_ac62b_row3_col7" class="data row3 col7" >0.0590</td>
#     </tr>
#     <tr>
#       <th id="T_ac62b_level0_row4" class="row_heading level0 row4" >dummy</th>
#       <td id="T_ac62b_row4_col0" class="data row4 col0" >Dummy Regressor</td>
#       <td id="T_ac62b_row4_col1" class="data row4 col1" >0.2178</td>
#       <td id="T_ac62b_row4_col2" class="data row4 col2" >2.6135</td>
#       <td id="T_ac62b_row4_col3" class="data row4 col3" >0.7165</td>
#       <td id="T_ac62b_row4_col4" class="data row4 col4" >-0.0044</td>
#       <td id="T_ac62b_row4_col5" class="data row4 col5" >0.1740</td>
#       <td id="T_ac62b_row4_col6" class="data row4 col6" >1.4466</td>
#       <td id="T_ac62b_row4_col7" class="data row4 col7" >0.0220</td>
#     </tr>
#     <tr>
#       <th id="T_ac62b_level0_row5" class="row_heading level0 row5" >lightgbm</th>
#       <td id="T_ac62b_row5_col0" class="data row5 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_ac62b_row5_col1" class="data row5 col1" >0.0981</td>
#       <td id="T_ac62b_row5_col2" class="data row5 col2" >2.9074</td>
#       <td id="T_ac62b_row5_col3" class="data row5 col3" >0.9609</td>
#       <td id="T_ac62b_row5_col4" class="data row5 col4" >-5.4479</td>
#       <td id="T_ac62b_row5_col5" class="data row5 col5" >0.1210</td>
#       <td id="T_ac62b_row5_col6" class="data row5 col6" >0.5957</td>
#       <td id="T_ac62b_row5_col7" class="data row5 col7" >0.2050</td>
#     </tr>
#     <tr>
#       <th id="T_ac62b_level0_row6" class="row_heading level0 row6" >gbr</th>
#       <td id="T_ac62b_row6_col0" class="data row6 col0" >Gradient Boosting Regressor</td>
#       <td id="T_ac62b_row6_col1" class="data row6 col1" >0.1257</td>
#       <td id="T_ac62b_row6_col2" class="data row6 col2" >3.0397</td>
#       <td id="T_ac62b_row6_col3" class="data row6 col3" >1.0126</td>
#       <td id="T_ac62b_row6_col4" class="data row6 col4" >-7.8959</td>
#       <td id="T_ac62b_row6_col5" class="data row6 col5" >0.1373</td>
#       <td id="T_ac62b_row6_col6" class="data row6 col6" >0.8117</td>
#       <td id="T_ac62b_row6_col7" class="data row6 col7" >1.3840</td>
#     </tr>
#     <tr>
#       <th id="T_ac62b_level0_row7" class="row_heading level0 row7" >rf</th>
#       <td id="T_ac62b_row7_col0" class="data row7 col0" >Random Forest Regressor</td>
#       <td id="T_ac62b_row7_col1" class="data row7 col1" >0.0864</td>
#       <td id="T_ac62b_row7_col2" class="data row7 col2" >3.5683</td>
#       <td id="T_ac62b_row7_col3" class="data row7 col3" >1.2298</td>
#       <td id="T_ac62b_row7_col4" class="data row7 col4" >-17.6302</td>
#       <td id="T_ac62b_row7_col5" class="data row7 col5" >0.1103</td>
#       <td id="T_ac62b_row7_col6" class="data row7 col6" >0.4900</td>

# %%
evaluate_model(best_global)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %%
predictions_train_global = predict_model(best_global, data= global_train)
# Out:
# <style type="text/css">
# </style>
# <table id="T_0bd85_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >MAE</th>
#       <th class="col_heading level0 col2" >MSE</th>
#       <th class="col_heading level0 col3" >RMSE</th>
#       <th class="col_heading level0 col4" >R2</th>
#       <th class="col_heading level0 col5" >RMSLE</th>
#       <th class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0bd85_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0bd85_row0_col0" class="data row0 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_0bd85_row0_col1" class="data row0 col1" >0.1080</td>
#       <td id="T_0bd85_row0_col2" class="data row0 col2" >1.8089</td>
#       <td id="T_0bd85_row0_col3" class="data row0 col3" >1.3450</td>
#       <td id="T_0bd85_row0_col4" class="data row0 col4" >0.0202</td>
#       <td id="T_0bd85_row0_col5" class="data row0 col5" >0.0993</td>
#       <td id="T_0bd85_row0_col6" class="data row0 col6" >0.7284</td>
#     </tr>
#   </tbody>
# </table>

# %%
predictions_train_global.groupby('producto').apply(r2_rmse).reset_index()
# Out:
#    producto       mae        r2
# 0         0  0.130456 -0.009635
# 1         1  0.085587  0.002660

# %%
predictions_test_global = predict_model(best_global, data= global_test)
# Out:
# <style type="text/css">
# </style>
# <table id="T_03fcb_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >MAE</th>
#       <th class="col_heading level0 col2" >MSE</th>
#       <th class="col_heading level0 col3" >RMSE</th>
#       <th class="col_heading level0 col4" >R2</th>
#       <th class="col_heading level0 col5" >RMSLE</th>
#       <th class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_03fcb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_03fcb_row0_col0" class="data row0 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_03fcb_row0_col1" class="data row0 col1" >0.1049</td>
#       <td id="T_03fcb_row0_col2" class="data row0 col2" >0.0214</td>
#       <td id="T_03fcb_row0_col3" class="data row0 col3" >0.1464</td>
#       <td id="T_03fcb_row0_col4" class="data row0 col4" >0.4883</td>
#       <td id="T_03fcb_row0_col5" class="data row0 col5" >0.1083</td>
#       <td id="T_03fcb_row0_col6" class="data row0 col6" >0.9180</td>
#     </tr>
#   </tbody>
# </table>

# %%
predictions_test_global.groupby('producto').apply(r2_rmse).reset_index()
# Out:
#    producto       mae        r2
# 0         0  0.140608 -0.294059
# 1         1  0.069186  0.137668

# %% [markdown]
# # 2. Basline Model using the Sales Lag 7

# %%
df_repsol2 = pd.read_csv('df_repsol(3).csv', index_col=1).drop(columns = ["Unnamed: 0"])
df_repsol2["station"] = df_repsol2["station"].str[2:]
df_repsol2["station"] = df_repsol2["station"].astype(int)
le = preprocessing.LabelEncoder()
df_repsol2['municipality'] = le.fit_transform(df_repsol2["municipality"].values)
df_repsol2['producto'] = 0
df_repsol2.loc[df_repsol2['product'] == '95', 'producto'] = 1

# %%
columns_strings2 = df_repsol2.dtypes[df_repsol2.dtypes == "object"].index
columns_strings2
# Out:
# Index(['product', 'horaracha', 'horatmax', 'horatmin', 'coordinates',
#        'provinces'],
#       dtype='object')

# %%
def r2_rmse(data):
    r2 = r2_score(data['sales_norm'], data['Label'] )
    mae =  mean_absolute_error(data['sales_norm'], data['Label'])
    return pd.Series(dict(mae = mae, r2 = r2))

# %%
df_repsol_model2 = df_repsol2.drop(columns = columns_strings)
df_repsol_model2.dropna(inplace = True)

# %%
global_train2 = df_repsol_model2.loc[(df_repsol_model2.index >= '2016-01-01')
                     & (df_repsol_model.index <= '2018-12-31')]

global_test2 = df_repsol_model2.loc[(df_repsol_model2.index >= '2019-01-01')
                     & (df_repsol_model.index <= '2019-01-31')]

# %%
df_repsol2[['sales_norm', 'lag7_sales']]
# Out:
#             sales_norm  lag7_sales
# date
# 2016-01-01    0.024927    0.024927
# 2016-01-02    0.064939    0.024927
# 2016-01-03    0.069706    0.024927
# 2016-01-04    0.094124    0.024927
# 2016-01-05    0.097476    0.024927
# ...                ...         ...
# 2019-01-27    0.360448    0.354203
# 2019-01-28    0.594835    0.620668
# 2019-01-29    0.546949    0.580848
# 2019-01-30    0.632972    0.590326
# 2019-01-31    0.608240    0.610956
#
# [25731 rows x 2 columns]

# %%
round(r2_score(global_train2['sales_norm'], global_train2['lag7_sales']),3)
# Out:
# 0.623

# %% [markdown]
# As expected, the r2 scores for both the training and test set are not very good.

# %%
print(f"Training Set R2 score for baseline model: {round(r2_score(global_train['sales_norm'], global_train['lag7_sales']),3)}")
# Out:
# Training Set R2 score for baseline model: 0.623

# %%
print(f"Testing Set R2 score for baseline model: {round(r2_score(global_test['sales_norm'], global_test['lag7_sales']),3)}")
# Out:
# Testing Set R2 score for baseline model: 0.632

# %% [markdown]
# # 3. Creating a Baseline Model using Linear Regression

# %% [markdown]
# Using some more complex methods, we managed to increase the R2 score, this time, using a Linear Regression Model.

# %%
X_train_global = global_train2.drop("sales_norm", axis=1)
Y_train_global = global_train2["sales_norm"]

X_test_global = global_test2.drop("sales_norm", axis=1)
Y_test_global = global_test2["sales_norm"]

# %%
setup_lr = setup(data = global_train2,  target = "sales_norm", silent = True)
# Out:
# <style type="text/css">
# #T_f61c1_row42_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_f61c1_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f61c1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f61c1_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_f61c1_row0_col1" class="data row0 col1" >880</td>
#     </tr>
#     <tr>
#       <th id="T_f61c1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f61c1_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_f61c1_row1_col1" class="data row1 col1" >sales_norm</td>
#     </tr>
#     <tr>
#       <th id="T_f61c1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f61c1_row2_col0" class="data row2 col0" >Original Data</td>
#       <td id="T_f61c1_row2_col1" class="data row2 col1" >(24987, 80)</td>
#     </tr>
#     <tr>
#       <th id="T_f61c1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f61c1_row3_col0" class="data row3 col0" >Missing Values</td>
#       <td id="T_f61c1_row3_col1" class="data row3 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f61c1_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f61c1_row4_col0" class="data row4 col0" >Numeric Features</td>
#       <td id="T_f61c1_row4_col1" class="data row4 col1" >66</td>
#     </tr>
#     <tr>
#       <th id="T_f61c1_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f61c1_row5_col0" class="data row5 col0" >Categorical Features</td>
#       <td id="T_f61c1_row5_col1" class="data row5 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_f61c1_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f61c1_row6_col0" class="data row6 col0" >Ordinal Features</td>
#       <td id="T_f61c1_row6_col1" class="data row6 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f61c1_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f61c1_row7_col0" class="data row7 col0" >High Cardinality Features</td>
#       <td id="T_f61c1_row7_col1" class="data row7 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f61c1_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f61c1_row8_col0" class="data row8 col0" >High Cardinality Method</td>
#       <td id="T_f61c1_row8_col1" class="data row8 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_f61c1_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f61c1_row9_col0" class="data row9 col0" >Transformed Train Set</td>
#       <td id="T_f61c1_row9_col1" class="data row9 col1" >(17490, 89)</td>
#     </tr>
#     <tr>
#       <th id="T_f61c1_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_f61c1_row10_col0" class="data row10 col0" >Transformed Test Set</td>
#       <td id="T_f61c1_row10_col1" class="data row10 col1" >(7497, 89)</td>
#     </tr>
#     <tr>
#       <th id="T_f61c1_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_f61c1_row11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#       <td id="T_f61c1_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_f61c1_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_f61c1_row12_col0" class="data row12 col0" >Stratify Train-Test</td>
#       <td id="T_f61c1_row12_col1" class="data row12 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f61c1_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_f61c1_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_f61c1_row13_col1" class="data row13 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_f61c1_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_f61c1_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_f61c1_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_f61c1_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_f61c1_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_f61c1_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_f61c1_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_f61c1_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_f61c1_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f61c1_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_f61c1_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_f61c1_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f61c1_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_f61c1_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_f61c1_row18_col1" class="data row18 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_f61c1_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_f61c1_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_f61c1_row19_col1" class="data row19 col1" >2d2c</td>
#     </tr>
#     <tr>
#       <th id="T_f61c1_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_f61c1_row20_col0" class="data row20 col0" >Imputation Type</td>
#       <td id="T_f61c1_row20_col1" class="data row20 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_f61c1_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_f61c1_row21_col0" class="data row21 col0" >Iterative Imputation Iteration</td>
#       <td id="T_f61c1_row21_col1" class="data row21 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_f61c1_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_f61c1_row22_col0" class="data row22 col0" >Numeric Imputer</td>
#       <td id="T_f61c1_row22_col1" class="data row22 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_f61c1_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_f61c1_row23_col0" class="data row23 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_f61c1_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_f61c1_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_f61c1_row24_col0" class="data row24 col0" >Categorical Imputer</td>
#       <td id="T_f61c1_row24_col1" class="data row24 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_f61c1_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_f61c1_row25_col0" class="data row25 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_f61c1_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_f61c1_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_f61c1_row26_col0" class="data row26 col0" >Unknown Categoricals Handling</td>
#       <td id="T_f61c1_row26_col1" class="data row26 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_f61c1_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_f61c1_row27_col0" class="data row27 col0" >Normalize</td>
#       <td id="T_f61c1_row27_col1" class="data row27 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f61c1_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_f61c1_row28_col0" class="data row28 col0" >Normalize Method</td>
#       <td id="T_f61c1_row28_col1" class="data row28 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_f61c1_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_f61c1_row29_col0" class="data row29 col0" >Transformation</td>
#       <td id="T_f61c1_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f61c1_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_f61c1_row30_col0" class="data row30 col0" >Transformation Method</td>
#       <td id="T_f61c1_row30_col1" class="data row30 col1" >None</td>
#     </tr>

# %% [markdown]
# #### Pycaret uses a default CV grid of 10 folds (we set it to 100 to get more consistent results), using 70% of the data as training data and 30% for validation

# %%
linear_model = create_model("lr", fold = numero)
# Out:
# <style type="text/css">
# #T_5c655_row100_col0, #T_5c655_row100_col1, #T_5c655_row100_col2, #T_5c655_row100_col3, #T_5c655_row100_col4, #T_5c655_row100_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_5c655_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MAE</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >RMSE</th>
#       <th class="col_heading level0 col3" >R2</th>
#       <th class="col_heading level0 col4" >RMSLE</th>
#       <th class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5c655_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5c655_row0_col0" class="data row0 col0" >0.0723</td>
#       <td id="T_5c655_row0_col1" class="data row0 col1" >0.0132</td>
#       <td id="T_5c655_row0_col2" class="data row0 col2" >0.1149</td>
#       <td id="T_5c655_row0_col3" class="data row0 col3" >0.7742</td>
#       <td id="T_5c655_row0_col4" class="data row0 col4" >0.0822</td>
#       <td id="T_5c655_row0_col5" class="data row0 col5" >0.3961</td>
#     </tr>
#     <tr>
#       <th id="T_5c655_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5c655_row1_col0" class="data row1 col0" >0.0683</td>
#       <td id="T_5c655_row1_col1" class="data row1 col1" >0.0104</td>
#       <td id="T_5c655_row1_col2" class="data row1 col2" >0.1021</td>
#       <td id="T_5c655_row1_col3" class="data row1 col3" >0.8112</td>
#       <td id="T_5c655_row1_col4" class="data row1 col4" >0.0739</td>
#       <td id="T_5c655_row1_col5" class="data row1 col5" >0.5096</td>
#     </tr>
#     <tr>
#       <th id="T_5c655_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5c655_row2_col0" class="data row2 col0" >0.0579</td>
#       <td id="T_5c655_row2_col1" class="data row2 col1" >0.0072</td>
#       <td id="T_5c655_row2_col2" class="data row2 col2" >0.0847</td>
#       <td id="T_5c655_row2_col3" class="data row2 col3" >0.8765</td>
#       <td id="T_5c655_row2_col4" class="data row2 col4" >0.0587</td>
#       <td id="T_5c655_row2_col5" class="data row2 col5" >0.2243</td>
#     </tr>
#     <tr>
#       <th id="T_5c655_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5c655_row3_col0" class="data row3 col0" >0.0539</td>
#       <td id="T_5c655_row3_col1" class="data row3 col1" >0.0058</td>
#       <td id="T_5c655_row3_col2" class="data row3 col2" >0.0763</td>
#       <td id="T_5c655_row3_col3" class="data row3 col3" >0.8863</td>
#       <td id="T_5c655_row3_col4" class="data row3 col4" >0.0517</td>
#       <td id="T_5c655_row3_col5" class="data row3 col5" >0.2208</td>
#     </tr>
#     <tr>
#       <th id="T_5c655_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5c655_row4_col0" class="data row4 col0" >0.0741</td>
#       <td id="T_5c655_row4_col1" class="data row4 col1" >0.0130</td>
#       <td id="T_5c655_row4_col2" class="data row4 col2" >0.1139</td>
#       <td id="T_5c655_row4_col3" class="data row4 col3" >0.7880</td>
#       <td id="T_5c655_row4_col4" class="data row4 col4" >0.0834</td>
#       <td id="T_5c655_row4_col5" class="data row4 col5" >0.5932</td>
#     </tr>
#     <tr>
#       <th id="T_5c655_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5c655_row5_col0" class="data row5 col0" >0.0567</td>
#       <td id="T_5c655_row5_col1" class="data row5 col1" >0.0066</td>
#       <td id="T_5c655_row5_col2" class="data row5 col2" >0.0809</td>
#       <td id="T_5c655_row5_col3" class="data row5 col3" >0.8846</td>
#       <td id="T_5c655_row5_col4" class="data row5 col4" >0.0561</td>
#       <td id="T_5c655_row5_col5" class="data row5 col5" >0.2431</td>
#     </tr>
#     <tr>
#       <th id="T_5c655_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_5c655_row6_col0" class="data row6 col0" >0.0667</td>
#       <td id="T_5c655_row6_col1" class="data row6 col1" >0.0087</td>
#       <td id="T_5c655_row6_col2" class="data row6 col2" >0.0933</td>
#       <td id="T_5c655_row6_col3" class="data row6 col3" >0.8329</td>
#       <td id="T_5c655_row6_col4" class="data row6 col4" >0.0646</td>
#       <td id="T_5c655_row6_col5" class="data row6 col5" >0.2611</td>
#     </tr>
#     <tr>
#       <th id="T_5c655_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_5c655_row7_col0" class="data row7 col0" >0.0602</td>
#       <td id="T_5c655_row7_col1" class="data row7 col1" >0.0081</td>
#       <td id="T_5c655_row7_col2" class="data row7 col2" >0.0898</td>
#       <td id="T_5c655_row7_col3" class="data row7 col3" >0.8569</td>
#       <td id="T_5c655_row7_col4" class="data row7 col4" >0.0625</td>
#       <td id="T_5c655_row7_col5" class="data row7 col5" >0.2460</td>
#     </tr>
#     <tr>
#       <th id="T_5c655_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_5c655_row8_col0" class="data row8 col0" >0.0671</td>
#       <td id="T_5c655_row8_col1" class="data row8 col1" >0.0111</td>
#       <td id="T_5c655_row8_col2" class="data row8 col2" >0.1055</td>
#       <td id="T_5c655_row8_col3" class="data row8 col3" >0.8000</td>
#       <td id="T_5c655_row8_col4" class="data row8 col4" >0.0755</td>
#       <td id="T_5c655_row8_col5" class="data row8 col5" >0.4101</td>
#     </tr>
#     <tr>
#       <th id="T_5c655_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_5c655_row9_col0" class="data row9 col0" >0.0607</td>
#       <td id="T_5c655_row9_col1" class="data row9 col1" >0.0069</td>
#       <td id="T_5c655_row9_col2" class="data row9 col2" >0.0828</td>
#       <td id="T_5c655_row9_col3" class="data row9 col3" >0.8751</td>
#       <td id="T_5c655_row9_col4" class="data row9 col4" >0.0566</td>
#       <td id="T_5c655_row9_col5" class="data row9 col5" >0.2242</td>
#     </tr>
#     <tr>
#       <th id="T_5c655_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_5c655_row10_col0" class="data row10 col0" >0.0785</td>
#       <td id="T_5c655_row10_col1" class="data row10 col1" >0.0113</td>
#       <td id="T_5c655_row10_col2" class="data row10 col2" >0.1062</td>
#       <td id="T_5c655_row10_col3" class="data row10 col3" >0.7873</td>
#       <td id="T_5c655_row10_col4" class="data row10 col4" >0.0720</td>
#       <td id="T_5c655_row10_col5" class="data row10 col5" >0.2698</td>
#     </tr>
#     <tr>
#       <th id="T_5c655_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_5c655_row11_col0" class="data row11 col0" >0.0743</td>
#       <td id="T_5c655_row11_col1" class="data row11 col1" >0.0120</td>
#       <td id="T_5c655_row11_col2" class="data row11 col2" >0.1097</td>
#       <td id="T_5c655_row11_col3" class="data row11 col3" >0.8010</td>
#       <td id="T_5c655_row11_col4" class="data row11 col4" >0.0780</td>
#       <td id="T_5c655_row11_col5" class="data row11 col5" >0.6008</td>
#     </tr>
#     <tr>
#       <th id="T_5c655_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_5c655_row12_col0" class="data row12 col0" >0.0638</td>
#       <td id="T_5c655_row12_col1" class="data row12 col1" >0.0083</td>
#       <td id="T_5c655_row12_col2" class="data row12 col2" >0.0910</td>
#       <td id="T_5c655_row12_col3" class="data row12 col3" >0.8448</td>
#       <td id="T_5c655_row12_col4" class="data row12 col4" >0.0626</td>
#       <td id="T_5c655_row12_col5" class="data row12 col5" >0.3006</td>
#     </tr>
#     <tr>
#       <th id="T_5c655_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_5c655_row13_col0" class="data row13 col0" >0.0630</td>
#       <td id="T_5c655_row13_col1" class="data row13 col1" >0.0081</td>
#       <td id="T_5c655_row13_col2" class="data row13 col2" >0.0898</td>
#       <td id="T_5c655_row13_col3" class="data row13 col3" >0.8449</td>
#       <td id="T_5c655_row13_col4" class="

# %%
predictions_train = predict_model(linear_model, data= global_train2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_ec9c3_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >MAE</th>
#       <th class="col_heading level0 col2" >MSE</th>
#       <th class="col_heading level0 col3" >RMSE</th>
#       <th class="col_heading level0 col4" >R2</th>
#       <th class="col_heading level0 col5" >RMSLE</th>
#       <th class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ec9c3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ec9c3_row0_col0" class="data row0 col0" >Linear Regression</td>
#       <td id="T_ec9c3_row0_col1" class="data row0 col1" >0.0647</td>
#       <td id="T_ec9c3_row0_col2" class="data row0 col2" >0.0090</td>
#       <td id="T_ec9c3_row0_col3" class="data row0 col3" >0.0947</td>
#       <td id="T_ec9c3_row0_col4" class="data row0 col4" >0.8351</td>
#       <td id="T_ec9c3_row0_col5" class="data row0 col5" >0.0666</td>
#       <td id="T_ec9c3_row0_col6" class="data row0 col6" >0.4477</td>
#     </tr>
#   </tbody>
# </table>

# %%
predictions_test = predict_model(linear_model, data= global_test2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_406bf_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >MAE</th>
#       <th class="col_heading level0 col2" >MSE</th>
#       <th class="col_heading level0 col3" >RMSE</th>
#       <th class="col_heading level0 col4" >R2</th>
#       <th class="col_heading level0 col5" >RMSLE</th>
#       <th class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_406bf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_406bf_row0_col0" class="data row0 col0" >Linear Regression</td>
#       <td id="T_406bf_row0_col1" class="data row0 col1" >0.0684</td>
#       <td id="T_406bf_row0_col2" class="data row0 col2" >0.0095</td>
#       <td id="T_406bf_row0_col3" class="data row0 col3" >0.0976</td>
#       <td id="T_406bf_row0_col4" class="data row0 col4" >0.7729</td>
#       <td id="T_406bf_row0_col5" class="data row0 col5" >0.0738</td>
#       <td id="T_406bf_row0_col6" class="data row0 col6" >0.5820</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Grouping by product, we can see the model struggling to predict the GOA sales the most as it gets an R2 of 24% in the test set.

# %%
predictions_train.groupby('producto').apply(r2_rmse).reset_index()
# Out:
#    producto       mae        r2
# 0         0  0.094060  0.438347
# 1         1  0.035378  0.769300

# %%
predictions_test.groupby('producto').apply(r2_rmse).reset_index()
# Out:
#    producto       mae        r2
# 0         0  0.092289  0.425676
# 1         1  0.044583  0.616747
